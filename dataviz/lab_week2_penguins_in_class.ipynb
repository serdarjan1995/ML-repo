# %%
# 🐼 warm up with pandas - import, and DIY dataframe

import pandas as pd

df = pd.DataFrame({
    'Borough': ['Brooklyn', 'Manhattan', 'Queens', 'Staten Island', 'Bronx'],
    '2020 Population': [2736074, 1694251, 2405464, 495747, 1472654],
    'Major Airport': [False, False, True, False, False]
})

# RUN this cell! shift + enter

# %%
# using square brackets [] notation
# how can I access the first cell in the 2020 population column?

# write code here
df['2020 Population']


# write another line of code that prints the 3rd cell of the borough column,
# and then the 3rd cell of the major airport column on a new line


df['Borough'][3]
# Out:
# 'Staten Island'

# %%
# matplot lib refresh!

# add a line of code that imports matplotlib
# NOTE: you're going to want to add this: %matplotlib inline
import matplotlib.pyplot as plt
# %matplotlib inline


# plot a BAR chart, borough vs. 2020 population
# and change the color from the default
# check out this documentation to help: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

fig = plt.figure()
plt.bar(df['Borough'], df['2020 Population'], color="green", label="2020 population")
plt.title('Population of cities in 2020')
plt.legend()
plt.plot()


# add code here
# Out:
# []

# %%
                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                              # install the dataset via pip, python package manager
# https://github.com/mcnakhaee/palmerpenguins

# RUN this cell!

# !pip install palmerpenguins
from palmerpenguins import load_penguins_raw

# load dataframe into variable called penguins
penguins = load_penguins_raw()
# Out:
# Requirement already satisfied: palmerpenguins in /usr/local/lib/python3.10/dist-packages (0.1.4)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from palmerpenguins) (2.1.4)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from palmerpenguins) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas->palmerpenguins) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->palmerpenguins) (2024.1)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas->palmerpenguins) (2024.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.2->pandas->palmerpenguins) (1.16.0)

# %%
# take a look @ the first 5 rows of the dataset
# with head()

penguins.head(5)
# Out:
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
#    Culmen Length (mm)  Culmen Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0                39.1               18.7                181.0         3750.0
# 1                39.5               17.4                186.0         3800.0
# 2                40.3               18.0                195.0         3250.0
# 3                 NaN                NaN                  NaN            NaN
# 4                36.7               19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
# hmmm, what is culmen?!
# read a little context about the data here:
# https://allisonhorst.github.io/palmerpenguins/articles/art.html

# culmen is upper ridge of the birds bill.

# %%
# let's rename those column names that include culmen
# what should we rename them so they are a little easier for non-penguin-specialists?

# the pattern for doing this with the rename function looks like this:
# dataframe = dataframe.rename(columns={'old_column_name': 'new_column_name'})
# read this documentation to see how:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.rename.html

# write code here
print(penguins.columns)
new_column_mapping = {
    'Culmen Length (mm)': 'Bill Length (mm)',
    'Culmen Depth (mm)': 'Bill Depth (mm)',
}
penguins = penguins.rename(columns=new_column_mapping)



# check it again with head()
penguins.head(5)
# Out:
# Index(['studyName', 'Sample Number', 'Species', 'Region', 'Island', 'Stage',
#        'Individual ID', 'Clutch Completion', 'Date Egg', 'Culmen Length (mm)',
#        'Culmen Depth (mm)', 'Flipper Length (mm)', 'Body Mass (g)', 'Sex',
#        'Delta 15 N (o/oo)', 'Delta 13 C (o/oo)', 'Comments'],
#       dtype='object')
#   studyName  Sample Number                              Species  Region  \
# 0   PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 1   PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2   PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3   PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4   PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
#
#       Island               Stage Individual ID Clutch Completion    Date Egg  \
# 0  Torgersen  Adult, 1 Egg Stage          N1A1               Yes  2007-11-11
# 1  Torgersen  Adult, 1 Egg Stage          N1A2               Yes  2007-11-11
# 2  Torgersen  Adult, 1 Egg Stage          N2A1               Yes  2007-11-16
# 3  Torgersen  Adult, 1 Egg Stage          N2A2               Yes  2007-11-16
# 4  Torgersen  Adult, 1 Egg Stage          N3A1               Yes  2007-11-16
#
#    Bill Length (mm)  Bill Depth (mm)  Flipper Length (mm)  Body Mass (g)  \
# 0              39.1             18.7                181.0         3750.0
# 1              39.5             17.4                186.0         3800.0
# 2              40.3             18.0                195.0         3250.0
# 3               NaN              NaN                  NaN            NaN
# 4              36.7             19.3                193.0         3450.0
#
#       Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 0    MALE                NaN                NaN
# 1  FEMALE            8.94956          -24.69454
# 2  FEMALE            8.36821          -25.33302
# 3     NaN                NaN                NaN
# 4  FEMALE            8.76651          -25.32426
#
#                          Comments
# 0  Not enough blood for isotopes.
# 1                             NaN
# 2                             NaN
# 3              Adult not sampled.
# 4                             NaN

# %%
# let's keep exploring the dataset
# get the "shape" of the dataset, using .shape
# the number of rows and columns (rows, columns)

# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.shape.html

rows, columns = penguins.shape
print(f"Total columns: {columns}")
print(f"Total rows: {rows}")
# Out:
# Total columns: 17
# Total rows: 344

# %%
# keep doing exploratory analysis, with .info() function
# summarize info: columns, non-null counts, and data type
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.info.html

# add code here
penguins.info(show_counts=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 344 entries, 0 to 343
# Data columns (total 17 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   studyName            344 non-null    object
#  1   Sample Number        344 non-null    int64
#  2   Species              344 non-null    object
#  3   Region               344 non-null    object
#  4   Island               344 non-null    object
#  5   Stage                344 non-null    object
#  6   Individual ID        344 non-null    object
#  7   Clutch Completion    344 non-null    object
#  8   Date Egg             344 non-null    object
#  9   Bill Length (mm)     342 non-null    float64
#  10  Bill Depth (mm)      342 non-null    float64
#  11  Flipper Length (mm)  342 non-null    float64
#  12  Body Mass (g)        342 non-null    float64
#  13  Sex                  333 non-null    object
#  14  Delta 15 N (o/oo)    330 non-null    float64
#  15  Delta 13 C (o/oo)    331 non-null    float64
#  16  Comments             54 non-null     object
# dtypes: float64(6), int64(1), object(10)
# memory usage: 45.8+ KB

# %%
# keep doing exploratory analysis, with .describe() function
# get statistics for each quantitative column/attribute
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.describe.html

penguins.describe()
# Out:
#        Sample Number  Bill Length (mm)  Bill Depth (mm)  Flipper Length (mm)  \
# count     344.000000        342.000000       342.000000           342.000000
# mean       63.151163         43.921930        17.151170           200.915205
# std        40.430199          5.459584         1.974793            14.061714
# min         1.000000         32.100000        13.100000           172.000000
# 25%        29.000000         39.225000        15.600000           190.000000
# 50%        58.000000         44.450000        17.300000           197.000000
# 75%        95.250000         48.500000        18.700000           213.000000
# max       152.000000         59.600000        21.500000           231.000000
#
#        Body Mass (g)  Delta 15 N (o/oo)  Delta 13 C (o/oo)
# count     342.000000         330.000000         331.000000
# mean     4201.754386           8.733382         -25.686292
# std       801.954536           0.551770           0.793961
# min      2700.000000           7.632200         -27.018540
# 25%      3550.000000           8.299890         -26.320305
# 50%      4050.000000           8.652405         -25.833520
# 75%      4750.000000           9.172123         -25.062050
# max      6300.000000          10.025440         -23.787670

# %% [markdown]
# What's the largest value in the Body Mass column?
# (6300)
#
# What's the standard deviation of Flipper Length?
# (14.06)
#
# What's going on with the Sample Number column?
# (Sample Number column is the categorical data - and there was a total of 152 different samples 1-152 )

# %%
# use the write to csv function to download and view the data in another platform
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.to_csv.html

import os

output_f_name = os.getcwd() + '/penguins_data.csv'
print(output_f_name)
penguins.to_csv(output_f_name)
# Out:
# /content/penguins_data.csv

# %%
# un-comment the following line of code:
penguins.count(axis=0, numeric_only=False)
# read documentation here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.count.html



# write in comments here - what does the count() table show?
# it count all non-null items in the dataframe
# Out:
# studyName              344
# Sample Number          344
# Species                344
# Region                 344
# Island                 344
# Stage                  344
# Individual ID          344
# Clutch Completion      344
# Date Egg               344
# Bill Length (mm)       342
# Bill Depth (mm)        342
# Flipper Length (mm)    342
# Body Mass (g)          342
# Sex                    333
# Delta 15 N (o/oo)      330
# Delta 13 C (o/oo)      331
# Comments                54
# dtype: int64

# %%
# compare the table results to the penguins.shape
# are some columns missing values?

penguins.shape

# RUN the following line of code:
print(penguins.isna().sum())
# documentation here: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.isna.html

# write in comments below: what does the isna table show?
# isna() counts numbers of null cells in the columns
# Out:
# studyName                0
# Sample Number            0
# Species                  0
# Region                   0
# Island                   0
# Stage                    0
# Individual ID            0
# Clutch Completion        0
# Date Egg                 0
# Bill Length (mm)         2
# Bill Depth (mm)          2
# Flipper Length (mm)      2
# Body Mass (g)            2
# Sex                     11
# Delta 15 N (o/oo)       14
# Delta 13 C (o/oo)       13
# Comments               290
# dtype: int64

# %%
# explore: how many different values are there for the 'island' column/attribute?
# use the value_counts() function
# documentation here: https://pandas.pydata.org/docs/reference/api/pandas.Series.value_counts.html

penguins['Island'].value_counts(normalize=False, sort=True, ascending=False, bins=None, dropna=True)
# Out:
# Island
# Biscoe       168
# Dream        124
# Torgersen     52
# Name: count, dtype: int64

# %%
# let's sort the data by flipper length
# this documentation should tell you how:
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.sort_values.html
penguins = penguins.sort_values("Flipper Length (mm)", axis=0, ascending=True, inplace=False, kind='quicksort', na_position='last', ignore_index=False, key=None)

# check that you've sorted right with head() ...
penguins[:10]
# Out:
#     studyName  Sample Number                                    Species  \
# 28    PAL0708             29        Adelie Penguin (Pygoscelis adeliae)
# 20    PAL0708             21        Adelie Penguin (Pygoscelis adeliae)
# 122   PAL0910            123        Adelie Penguin (Pygoscelis adeliae)
# 30    PAL0708             31        Adelie Penguin (Pygoscelis adeliae)
# 31    PAL0708             32        Adelie Penguin (Pygoscelis adeliae)
# 282   PAL0708              7  Chinstrap penguin (Pygoscelis antarctica)
# 98    PAL0809             99        Adelie Penguin (Pygoscelis adeliae)
# 47    PAL0708             48        Adelie Penguin (Pygoscelis adeliae)
# 29    PAL0708             30        Adelie Penguin (Pygoscelis adeliae)
# 21    PAL0708             22        Adelie Penguin (Pygoscelis adeliae)
#
#      Region     Island               Stage Individual ID Clutch Completion  \
# 28   Anvers     Biscoe  Adult, 1 Egg Stage         N18A1                No
# 20   Anvers     Biscoe  Adult, 1 Egg Stage         N11A1               Yes
# 122  Anvers  Torgersen  Adult, 1 Egg Stage         N67A1               Yes
# 30   Anvers      Dream  Adult, 1 Egg Stage         N21A1               Yes
# 31   Anvers      Dream  Adult, 1 Egg Stage         N21A2               Yes
# 282  Anvers      Dream  Adult, 1 Egg Stage         N66A1               Yes
# 98   Anvers      Dream  Adult, 1 Egg Stage         N50A1               Yes
# 47   Anvers      Dream  Adult, 1 Egg Stage         N29A2               Yes
# 29   Anvers     Biscoe  Adult, 1 Egg Stage         N18A2                No
# 21   Anvers     Biscoe  Adult, 1 Egg Stage         N11A2               Yes
#
#        Date Egg  Bill Length (mm)  Bill Depth (mm)  Flipper Length (mm)  \
# 28   2007-11-10              37.9             18.6                172.0
# 20   2007-11-12              37.8             18.3                174.0
# 122  2009-11-16              40.2             17.0                176.0
# 30   2007-11-09              39.5             16.7                178.0
# 31   2007-11-09              37.2             18.1                178.0
# 282  2007-11-28              46.1             18.2                178.0
# 98   2008-11-10              33.1             16.1                178.0
# 47   2007-11-13              37.5             18.9                179.0
# 29   2007-11-10              40.5             18.9                180.0
# 21   2007-11-12              37.7             18.7                180.0
#
#      Body Mass (g)     Sex  Delta 15 N (o/oo)  Delta 13 C (o/oo)  \
# 28          3150.0  FEMALE            8.38404          -25.19837
# 20          3400.0  FEMALE            8.73762          -25.09383
# 122         3450.0  FEMALE            9.30722          -25.61039
# 30          3250.0  FEMALE            9.69756          -25.11223
# 31          3900.0    MALE            9.72764          -25.01020
# 282         3250.0  FEMALE            8.85664          -24.55644
# 98          2900.0  FEMALE            9.04218          -26.15775
# 47          2975.0     NaN                NaN                NaN
# 29          3950.0    MALE            8.90027          -25.11609
# 21          3600.0    MALE            8.66271          -25.06390
#
#                                               Comments
# 28               Nest never observed with full clutch.
# 20                                                 NaN
# 122                                                NaN
# 30                                                 NaN
# 31                                                 NaN
# 282                                                NaN
# 98                                                 NaN
# 47   Sexing primers did not amplify. Not enough blo...
# 29               Nest never observed with full clutch.
# 21                                                 NaN

# %%
# what is the standard deviation of the quantiataive attributes - how far are values from the mean?
# use .std() function
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.std.html

penguins.std(axis=0, skipna=True, ddof=1, numeric_only=True)


# what happens when skipna = False?
# NA values makes computation impossible. it is like divide by zero, but just makes entire result NA if any columns contains NA values
# Out:
# Sample Number          40.430199
# Bill Length (mm)             NaN
# Bill Depth (mm)              NaN
# Flipper Length (mm)          NaN
# Body Mass (g)                NaN
# Delta 15 N (o/oo)            NaN
# Delta 13 C (o/oo)            NaN
# dtype: float64

# %%
# what about creating a smaller DataFrame, just bill length vs species?
# a subset of the full data
# the pattern for this:
# NEW_DATAFRAME_NAME = OLD_DATAFRAME["Column A", "Column B"]
penguins.columns
penguin_species_and_bill_len = penguins[["Species", "Bill Length (mm)"]]

penguin_species_and_bill_len.head()
# Out:
#                                Species  Bill Length (mm)
# 0  Adelie Penguin (Pygoscelis adeliae)              39.1
# 1  Adelie Penguin (Pygoscelis adeliae)              39.5
# 2  Adelie Penguin (Pygoscelis adeliae)              40.3
# 3  Adelie Penguin (Pygoscelis adeliae)               NaN
# 4  Adelie Penguin (Pygoscelis adeliae)              36.7

# %%
# write a line of code that shows the first 10 values
# of the smaller DataFrame, just bill lenght vs. species
# and SORT that data from highest -> lowest

penguin_species_and_bill_len = penguin_species_and_bill_len.sort_values("Bill Length (mm)", ascending=False)
penguin_species_and_bill_len.head(10)
# Out:
#                                        Species  Bill Length (mm)
# 293  Chinstrap penguin (Pygoscelis antarctica)              58.0
# 315  Chinstrap penguin (Pygoscelis antarctica)              53.5
# 301  Chinstrap penguin (Pygoscelis antarctica)              52.0
# 299  Chinstrap penguin (Pygoscelis antarctica)              50.6
# 199          Gentoo penguin (Pygoscelis papua)              50.5
# 302  Chinstrap penguin (Pygoscelis antarctica)              50.5
# 292  Chinstrap penguin (Pygoscelis antarctica)              50.3
# 277  Chinstrap penguin (Pygoscelis antarctica)              50.0
# 193          Gentoo penguin (Pygoscelis papua)              49.6
# 341  Chinstrap penguin (Pygoscelis antarctica)              49.6

# %%
# if we are going to visualize this, we could choose to get rid of NA outliers
# use the .dropna() function to do this
# documentation: https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.dropna.html


# write a line of code that re-writes the same dataframe
# and drops the NA values
penguin_species_and_bill_len = penguin_species_and_bill_len.dropna()

# for future reading:
# more context on missing values: https://jakevdp.github.io/PythonDataScienceHandbook/03.04-missing-values.html

# %%
# get the "shape" of this newest DataFrame (with the NA dropped)
penguin_species_and_bill_len.shape
# write here in comments - how many rows were dropped?

# we dropped every single line that contains NA - missing value. total of 310 records were dropped
# Out:
# (342, 2)

# %%
# let's look @ the mean of the bill length, by species
# documentation on groupby: https://pandas.pydata.org/docs/user_guide/groupby.html

penguin_species_and_bill_len.groupby('Species')['Bill Length (mm)'].mean()
# Out:
# Species
# Adelie Penguin (Pygoscelis adeliae)          38.791391
# Chinstrap penguin (Pygoscelis antarctica)    48.833824
# Gentoo penguin (Pygoscelis papua)            47.504878
# Name: Bill Length (mm), dtype: float64

# %%
# let's start with a scatter plot of just this data, species + bill length
# working with the matplotlib defaults ...

# write a line of code that creates a SCATTERPLOT
# with Species on the x-axis, and Bill Length as the y-axis
# remember: plt.scatter(x, y, options)
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html


plt.scatter(penguin_species_and_bill_len['Species'], penguin_species_and_bill_len['Bill Length (mm)'])
# penguin_species_and_bill_len.shape
# Out:
# (342, 2)

# %%
# NOW! if I want to show each species in a different color, I should filter my data
# I want 1 dataframe per species

# how can I FILTER the data so that all the Adelie penguins are in a DataFrame called adelie
# all the Gentoo penguins are in a DataFrame called gentoo
# and all the Chinstrap penguins are in a DataFrame called chinstrap?
df = penguin_species_and_bill_len
adelie = df.loc[df['Species'] == "Adelie Penguin (Pygoscelis adeliae)"]
chinstrap = df.loc[df['Species'] == "Chinstrap penguin (Pygoscelis antarctica)"]
gentoo = df.loc[df['Species'] == "Gentoo penguin (Pygoscelis papua)"]

# check this out if you need a hint or example:
# https://www.statology.org/pandas-select-rows-based-on-column-values/

# %%
# use .head() to check your 3 new dataframes

adelie.head()
chinstrap.head()
gentoo.head(10)
# Out:
#                                Species  Bill Length (mm)
# 152  Gentoo penguin (Pygoscelis papua)              46.1
# 153  Gentoo penguin (Pygoscelis papua)              50.0
# 154  Gentoo penguin (Pygoscelis papua)              48.7
# 155  Gentoo penguin (Pygoscelis papua)              50.0
# 156  Gentoo penguin (Pygoscelis papua)              47.6
# 157  Gentoo penguin (Pygoscelis papua)              46.5
# 158  Gentoo penguin (Pygoscelis papua)              45.4
# 159  Gentoo penguin (Pygoscelis papua)              46.7
# 160  Gentoo penguin (Pygoscelis papua)              43.3
# 161  Gentoo penguin (Pygoscelis papua)              46.8

# %%
# now we can plot the 3 species individually, with different options!

# write 3 lines of code to put the 3 species scatters on the same plot
# species = x-axis, bill length = y-axis
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.scatter.html

plt.scatter('Species', 'Bill Length (mm)', data=adelie, color='red', alpha=0.5, s=100, marker="o", label="Adelie Bill Length")
plt.scatter('Species', 'Bill Length (mm)', data=gentoo, color='blue', alpha=0.5, s=100, marker="d", label="Gentoo Bill Length")
plt.scatter('Species', 'Bill Length (mm)', data=chinstrap, color='green', alpha=0.5, s=100, marker="h", label="Chinstrap Bill Length")
plt.legend()
plt.xticks(rotation=5, ha='right')

# choose a different COLOR for each species
# play with alpha value and size for your visualization
# Out:
# ([0, 1, 2],
#  [Text(0, 0, 'Adelie Penguin (Pygoscelis adeliae)'),
#   Text(1, 0, 'Gentoo penguin (Pygoscelis papua)'),
#   Text(2, 0, 'Chinstrap penguin (Pygoscelis antarctica)')])

# %%
# CHECKPOINT: let's do this one together as a class

# to examine the mean along with the scatter, let's add a boxplot to each species
# matplotlib docs: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.boxplot.html#

y_data = [adelie["Bill Length (mm)"], gentoo["Bill Length (mm)"], chinstrap["Bill Length (mm)"]]

# remember the pattern! plt.type(data, options)
plt.boxplot(y_data, positions=[0, 1, 2])

# pattern: plt.scatter(x, y, options)
# to match the box plots to the scatter plots, we assign:
# adelie = 0, gentoo = 1, chinstrap = 2
# x values here need to be a list the same length as the y list
plt.scatter([0]*len(adelie), adelie["Bill Length (mm)"], color="Orange", alpha = 0.5, s = 100)
plt.scatter([1]*len(gentoo), gentoo["Bill Length (mm)"], color="Teal", alpha = 0.5, s = 100)
plt.scatter([2]*len(chinstrap), chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.5, s = 100)

# %%
# let's do some data transformation, and "jitter" the dots

# for each species, I want to have an x_data list, small random numbers in a range near their x value
# the list of x values needs to be the same length as the list of y values

# let's do some data transformation, and "jitter" the dots

import random

# for each species, I want to have an x_data list, small random numbers in a range near their x value
# the list of x values needs to be the same length as the list of y values
x_adelie = [random.uniform(-0.1, 0.1) + 0 for numbers in range(len(adelie))]
print(x_adelie)

x_gentoo = [random.uniform(-0.1, 0.1) + 1 for numbers in range(len(gentoo))]
x_chinstrap = [random.uniform(-0.1, 0.1) + 2 for numbers in range(len(chinstrap))]

plt.scatter(x_adelie, adelie["Bill Length (mm)"], color="Orange", alpha = 0.3, s = 80)
plt.scatter(x_gentoo, gentoo["Bill Length (mm)"], color="Teal", alpha = 0.3, s = 80)
plt.scatter(x_chinstrap, chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.3, s = 80)
# Out:
# [-0.02606864729912499, -0.008611228044200697, 0.04148847929760621, -0.010720566713513513, 0.05651502714321344, -0.02151927177874846, 0.02394742622213694, 0.014840805476291435, 0.049706463816107604, -0.007893520991298655, 0.08126496129360136, 0.0365016439041517, 0.014453328371575008, 0.08146402024160604, -0.0016922542348098701, 0.07723057376070849, -0.022381445493525415, -0.09261986287763627, -0.04921319312054709, -0.04324790165331685, -0.09691250982673823, -0.07271853045769293, 0.03754864092009397, -0.09702842344866876, 0.05560934305918461, 0.04725084371709354, -0.030365807814062534, 0.03535539204690458, -0.04349419405302984, 0.015886590756093777, -0.09827501547481993, -0.09846332896453254, 0.06867355826442617, 0.08164527678280539, 0.07956454383746184, -0.008787469365414788, -0.03670479548163988, -0.09360393577778854, 0.026995880192152516, 0.011559976819819323, -0.02758962594677715, -0.07975512747162594, 0.09671698025973599, -0.04775751129365222, -0.09248531189639182, 0.09535011959876621, -0.04775587686218579, 0.06351205939245771, -0.07446474827260614, 0.07358526442440366, -0.04073456885331548, -0.09591469901064105, -0.04887755290962124, 0.02299096782596359, 0.06920366846385173, 0.08544011530412618, 0.05889185327660604, -0.08211431456931143, 0.01969364016255873, -0.007554323230198001, 0.07209266640371886, -0.056636925854363335, 0.016098626864322133, -0.025120802101264175, 0.04616482910487113, 0.025260938278226064, 0.03498750635867637, -0.040531629274073014, -0.07821840813821657, -0.05983822381099549, -0.08755588563791346, 0.0892318913159808, -0.06866609955142763, 0.01760786809068353, 0.025630570384023776, 0.09897822076833446, 0.07583796503899484, 0.029869913390923764, -0.02531721969391265, -0.05687992246180682, -0.05079874917521104, -0.06370727285169353, -0.008139520797636399, -0.08217892389613045, 0.030563887058201067, 0.013456850466222248, 0.04247473377532068, -0.0855889967355633, -0.039862832603876734, 0.014125462900613561, -0.07603389978328173, 0.041087637151537654, 0.01508458379266231, 0.07874599407778479, 0.08718175067341705, 0.03845622132466672, 0.08034434613420055, -0.03100921998687227, -0.03221199340278445, -0.027139939142046862, -0.08586038101062024, -0.00424998196590623, -0.07612671496899666, 0.012902197024685758, -0.026444828404972975, 0.04830619602002903, -0.004162561735405662, 0.08144815600568664, -0.013271783053959998, 0.08502671695021263, 0.08606952498712753, 0.06612246381525175, 0.06252736865205716, 0.05225851947674379, 0.020061840117736124, 0.09312999726279306, -0.03458444274122861, 0.02749325240530326, -0.08074700386531877, -0.06354454683385932, 0.0432825971296541, 0.09669424123633685, -0.05175127250914671, 0.05445231511556345, -0.09617267346322755, 0.07422943694843101, 0.038634831990619206, 0.08865060105215647, 0.024524843910636696, 0.02496575511024897, 0.03910021442827122, 0.040003250748676056, -0.054391466356553675, -0.0271435835734702, -0.07409626802768066, 0.04204793352653696, 0.05712266236354041, 0.06226394296625534, 0.009911640456563162, -0.09034883863187303, 0.028817547285572898, -0.02498015308483674, -0.08834368355416417, -0.0641184185671086, 0.030316422648124425, -0.03204801666380504, 0.03201591972012416, 0.0319555480555789, -0.03797147232711687, -0.09195867365931681, -0.005597634237378982]

# %%
# reproducing the plot ...
plt.figure(figsize=(14, 10))
# figsize = inches!

plt.boxplot(y_data, positions=[0, 1, 2], medianprops={"color": "Red", "linewidth": 2})

plt.scatter(x_adelie, adelie["Bill Length (mm)"], color="Orange", alpha = 0.3, s = 80)
plt.scatter(x_gentoo, gentoo["Bill Length (mm)"], color="Teal", alpha = 0.3, s = 80)
plt.scatter(x_chinstrap, chinstrap["Bill Length (mm)"], color="Purple", alpha = 0.3, s = 80)


# but let's clean up the axes, titles, text, font, etc.!
# https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html
plt.rcParams["font.family"] = "monospace"
plt.xticks([0, 1, 2], ["Adelie", "Gentoo", "Chinstrap"], rotation=0, ha='center')
plt.ylabel("Bill Length (mm)")
plt.xlabel("Penguin Species")
plt.title("\nDistribution of Bill Length Across Penguin Species\n", pad=10, fontsize=18)

# and save it
plt.savefig("violin.png", dpi=500, format="png")

# %%
# nice!
# now ... let's go back to the larger penguin dataset
# and plot flipper length vs. body mass, across the whole dataset
# 1 line of code, scatterplot
# flipper lenght = x-axis, body mass = y-axis

# add your code here

# %%
# ok ... but now we want to filter the dataset to get 3 species, differentiated

# first getting a smaller dataframe: all rows, just columns flipper length, body mass, and species

# add code here

# %%
# now drop any NA missing values in this new dataframe

# %%
# NOW make filtered dataframes for each species:
# i.e., an adelie table with only flipper length, body mass, and species
# repeat for gentoo and chinstrap
# so that we can plot each species with different parameters



# test adelie out, using .head()

# %%
plt.figure(figsize=(10, 8))

# use color AND marker channels, to show 3 different species
# on the same scatterplot, bill length vs. body mass
# documentation for markers: https://matplotlib.org/stable/api/markers_api.html#module-matplotlib.markers



# add legend, labels, and title

# %%
# 📄 documentation cheatsheet!

# bar chart: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.bar.html

# histogram: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.hist.html

# titles: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.title.html

# axis labels: https://matplotlib.org/stable/api/_as_gen/matplotlib.pyplot.xlabel.html

# colors: https://matplotlib.org/stable/tutorials/colors/colors.html

# annotations: https://matplotlib.org/stable/gallery/text_labels_and_annotations/annotation_basic.html

# fonts: https://matplotlib.org/stable/gallery/text_labels_and_annotations/fonts_demo_kw.html

# more fonts: https://matplotlib.org/stable/gallery/text_labels_and_annotations/font_family_rc.html

# %%
# using the penguins dataframe, can you make a HISTOGRAM for the body mass attribute,
# where the plot shows 3 species in different colors?
# make sure to label your axes and add a title 🎨

# %%
# challenge: create a bar chart, with (at least) 2 variables of your choice
# (how will you get the counts for the y-axis?)
# make sure to label your axes and add a title 🎨

# %%
# if you have more time: annotate some features of your plots
# https://matplotlib.org/stable/tutorials/text/annotations.html

# %% [markdown]
# ## 🪼 when you are finished! submit: 🖇️
#
# 1. Download this notebook as an `.ipynb` file (File -> Download)
# 2. Go to [this link](https://airtable.com/app6HibgdChLzfvNP/shrYWYvDm5Eviq8bY) and upload the file via the form.
# 3. Then you're done! In-class labs are counted as participation credit.

# %% [markdown]
# **🧊🐧 citations:**
# - violin inspiration: https://python-graph-gallery.com/web-ggbetweenstats-with-matplotlib/ Tuo Wang, Tomas Capretto
# - original dataset and examples: https://allisonhorst.github.io/palmerpenguins/index.html
# - palmerpenguins python package: https://github.com/mcnakhaee/palmerpenguins
# - Brian Byrne [notebook](https://colab.research.google.com/drive/1RUzNHKpLCGuik_hpVLfto5bSH_KFaqJb) and [video](https://www.youtube.com/watch?v=qzW-Zx4HIK0)
