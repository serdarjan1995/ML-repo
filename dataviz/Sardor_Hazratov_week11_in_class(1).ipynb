# %%
# import libraries: plotly, networkx, and json

import plotly.graph_objects as go
import networkx as nx
import json

# %%
# read my json data

# source: https://lombardinetworks.net/networks/the-networks/ -
# this one is "Banco Nazionale del Lavoro, Reagan, Bush, Thatcher, and the Arming of Iraq, c. 1979-1990 (4th version)"
# original image: http://www.moma.org/collection/works/82619


with open('/content/lombardi1023-banco-lavoro.json', 'r') as f:
    data = json.load(f)
print(data)
# Out:
# {'nodes': [{'id': '9772', 'name': '[2]', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9770', 'name': '91/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}, {'id': '9767', 'name': '89/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}, {'id': '9764', 'name': '87/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}, {'id': '889', 'name': 'Agha Hasan Abedi', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9759', 'name': 'Jean-Luc Lagadere', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9756', 'name': 'Car and Driver', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9754', 'name': "Woman's Day", 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9751', 'name': 'Hachette Livres - Paris -', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9749', 'name': 'Ohanes Awanes Artin', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9747', 'name': 'Bruno Buhler', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9745', 'name': 'AHA Turnkey Projects - Vienna -', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9743', 'name': 'Mowafak Abdul Karim', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9737', 'name': 'Midis Fin - Geneva -', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9734', 'name': 'Mohammed Habib', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9731', 'name': 'Khalaf al-Doulimi', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9729', 'name': 'Montana Mgmt - Panama -', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9727', 'name': 'Aladine Hussein Khamas', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9725', 'name': 'Barzan al-Tikriti dir Iraqi Intelligence gov Kuwait 1990-1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '356', 'name': '?', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9721', 'name': 'Khairallah al-Tulfah', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9718', 'name': 'BAII', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9715', 'name': '1st City Bk - Houston -', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9713', 'name': 'Marshall Wiley US amb to Oman 1979-81', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9710', 'name': 'Richard Murphy dep asst sec US State dept', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9707', 'name': 'Richard Fairbanks US amb', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9705', 'name': 'US-Iraq Business Forum - Houston -', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9702', 'name': 'Paul Hastings Janofsky - DC -', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9701', 'name': 'James Plache dep US embassy Riyadh', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9699', 'name': 'Nizar Hamdoon Iraq amb to UN', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9697', 'name': 'Tarik Aziz foreign min', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}, {'id': '9695', 'name': 'Foreign Min/2', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}, {'id': '9693', 'name': '86/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}, {'id': '9691', 'name': '85/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}, {'id': '9688', 'name': '83/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}, {'id': '2283', 'name': '84/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}, {'id': '96 ...

# %%
# let's print out some things to know what our JSON (OBJECT) data looks like

for object in data:
  print(object)

# loop through the first list, nodes
for i in range(0, 5):
  print(data["nodes"][i])

# loop through the second list, links
for i in range(0, 5):
  print(data["links"][i])


# what are the lengths of both of these lists?
nodes = data["nodes"]
links = data["links"]
print(len(nodes))
print(len(links))
# Out:
# nodes
# links
# {'id': '9772', 'name': '[2]', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}
# {'id': '9770', 'name': '91/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}
# {'id': '9767', 'name': '89/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}
# {'id': '9764', 'name': '87/1', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Year'}
# {'id': '889', 'name': 'Agha Hasan Abedi', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Person'}
# {'source': '9770', 'target': '9772', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#YearArrow'}
# {'source': '9767', 'target': '9523', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#YearArrow'}
# {'source': '9764', 'target': '9501', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#YearArrow'}
# {'source': '889', 'target': '9150', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#InfluenceControl'}
# {'source': '9759', 'target': '9527', 'amount': '', 'type': 'http://www.lombardinetworks.net/lombardi.owl#InfluenceControl'}
# 342
# 428

# %%
# inside the "nodes" list,
# let's take a look @ the names property for each object

print(data["nodes"][0])

for node in data["nodes"]:
  print(node["name"])
# Out:
# {'id': '9772', 'name': '[2]', 'type': 'http://www.lombardinetworks.net/lombardi.owl#Institution'}
# [2]
# 91/1
# 89/1
# 87/1
# Agha Hasan Abedi
# Jean-Luc Lagadere
# Car and Driver
# Woman's Day
# Hachette Livres - Paris -
# Ohanes Awanes Artin
# Bruno Buhler
# AHA Turnkey Projects - Vienna -
# Mowafak Abdul Karim
# Midis Fin - Geneva -
# Mohammed Habib
# Khalaf al-Doulimi
# Montana Mgmt - Panama -
# Aladine Hussein Khamas
# Barzan al-Tikriti dir Iraqi Intelligence gov Kuwait 1990-1
# ?
# Khairallah al-Tulfah
# BAII
# 1st City Bk - Houston -
# Marshall Wiley US amb to Oman 1979-81
# Richard Murphy dep asst sec US State dept
# Richard Fairbanks US amb
# US-Iraq Business Forum - Houston -
# Paul Hastings Janofsky - DC -
# James Plache dep US embassy Riyadh
# Nizar Hamdoon Iraq amb to UN
# Tarik Aziz foreign min
# Foreign Min/2
# 86/1
# 85/1
# 83/1
# 84/1
# Abdul M. Rasheed
# Jasim Khalaf
# Addulwalad Toma
# Rafidain Bank - Baghdad -
# Iraq Central Bank
# Sadik Taha
# 81/1
# Gov't of Iraq
# Micro Tech & Comp - Austin -
# 1998: Atlanta Ga branch raided by FBI; 1991: US atty files charges against bank officials & clients; US House Banking Comm open hearings on bank; US taxpayers forfeit $ 370 mil
# 1991: Italian Senate opens probe of bank; recommends indictments; Italian taxpayers forfeit $ 400 mil
# (o)
# Nash Rehmann
# 90/3
# Richard Thornburgh atty gen US 1988-91
# Assoc Inst Dists - Ga -
# William Newlin
# John Mitchell atty gen US 1969-72
# Col. Jack Brennan
# Global Research Assocs - DC -
# Pathlite - Tenn -
# Spiro Agnew vp US 1969-73
# Pan East - Tenn -
# Nicolae Ceaucescu pres Romania 1965-89
# Pan Aviation - Miami -
# Sir Derek Alun-Jones
# Ferranti - London -
# Citicorp - NY -
# Saudi joint venture
# Roger Darman dir OMB 1989-93 dep sec US Treasury 1985-7
# James A. Baker III US sec State 1989-92 US sec Treas 1985-8
# Carlyle Group - DC -
# Frank Carlucci US sec Defense 1987-9 NSC 1986-7 dep dir CIA 1978-81
# Wackenhut Corp - Fl -
# Westmark Systems - Austin -
# Bobby Ray Inman dep dir CIA 1981-2 dir NSA 1977-81
# Worldwide Assocs
# Gen. Alexander Haig cmdr NATO 1979-81 US sec State 1981-2
# Gen. Barry Shillito
# 1992: raided by US Costums; forfeited $ 8.6 mil
# Swissco Dev. - Miami -
# 1992-3: indicted in US for arms smuggling & money laundering
# Carlos Cardoen
# Augusto Giangrandini
# James Theberge US amb to Chile 1982-5 CIA Panel 1986-7
# Juan Valdevieso
# Carlos Schurmann
# Nasser Beydoun
# Int'l Signal & Control - Pa -
# P.W. Botha pres So Africa 1984-9 PM 1978-84
# Gamma Systems - Jamaica NY -
# Gov't of South Africa
# 1991: indicted in US for arms smuggling
# Claude Ivy
# 1991: indicted in US for fraud & arms smuggling; plead guilty; sentenced to 15 yrs
# Ayatollah Ruhallah Khomeini r. Iran 1979-89
# Gov't of Iran
# John Major PM UK 1990-
# Margaret Thatcher PM UK 1979-90
# Alan Clark
# UK Gov't
# Norman Lamont
# Defense Min/2
# Gerard Heneghean
# James Guerin
# Terry Byrne
# Luchaire - Paris -
# Int'l Military Services
# George (Lord) Younger
# Royal Bank of Scotland
# Gary Kauf
# Iraqi uniform deal
# Armscor - Pretoria -
# Allivane - Glasgow -
# Saudi Int'l Bank
# Ameer Saadi
# Matra
# MBB
# 90/1
# covert weapons projects
# Christopher Cowley
# Alex Pappas
# Tom McCann
# Stephan Kock
# Chris Gumbley
# Astra Holding - London -
# Sir Gerald James
# Astra Defense Systems
# Jean Duronsoy
# 88/1
# 1991: indicted in US for fraud & conspiracy
# Daimler Benz - Stuttgart -
# Adel al-Alami
# Raja Hasan Ali
# 1995: defected to Jordan 1996 murdered upon return to Baghdad
# Saddam Hussein pres Iraq 1979-
# Hussein Kamel dir Min of Industry and Military Industrialization
# Fadel Kadhum
# Namir al-Naimi
# Learfan - Belfast -
# Anees M. Wadi
# Roy Ricks
# Safa al-Habobi
# TDG - London -
# Al Araby Trading - Baghdad -
# Robert Koshaba
# 1990: raided by UK customs police; charges later dismissed
# Paul Henderson
# Mark Gutteridge
# Abdul Qaddumi
# 1990: seized in US; assets forteited
# Dan Quayle vp US 1989-93
# Beurt Servaas
# Kennametal - Latrobe Fla -
# Gordon Cooper
# Roland Davis
# Richard Kendrick
# Bill Muscarella
# XYZ Options - Alabama -
# Salim Naman
# 1991: indicted in US for arms smuggling; convicted; sentenced to 4 yrs
# Sarkis Saghanalian
# Umberto D'Addosio
# Servaas Inc. - Indiana -
# Matrix Churchill US - Ohio -
# CE Kintex - Sofia -
# Stroock Stroock Lavan - NY -
# Mela Maggi
# Dale Toler
# RD&D - Va -
# 1991: murdered in Brussels by unknown assailants
# Gerald Bull
# Matrix Churchill UK - Coventry -
# Ind. Cardoen - Chile -
# Rexon Tech - NJ -
# ATI Belgique - Brussels -
# PRB - Brussels -
# SRC Composite - London -
# Paragon Holding - Panama -
# SRC Eng - London -
# Lloyd's Bank Int'l - London -
# 1991: convicted in UK; sentenced to 5 yrs
# Ali Daghir
# Euromac UK - London -
# 1989: raided by Italian police
# SRC Corp - Brussels -
# 1989: indicted in Italy; charges later dismissed
# Kassim Abbas
# TMG Eng - Baghdad -
# Euromac - Monza -
# Dow Chemical
# Arbed Steel - Lux -
# Foodline Corp
# Cecil Phillips
# Pacific Export
# Delft Insts - Neth -
# Hussein Zeineddine
# Int'l Trading Group - Paris -
# Hughes Aircraft - Calif -
# General Motors - Detroit -
# Thomsen CSF - Paris -
# Rinaldo Petrignani Italian amb to US
# William P. Rogers US sec State 1969-73
# Casper Weinberger US sec Defense 1981-7
# ASEA Brown Boveri
# George Shultz US sec State 1982-9 US sec Treas 1972-4
# proposed PC 2 plant
# Bechtel Corp - SF -
# Lummus Crest - NJ -
# MIMI
# proposed pipeline project
# Ahmed Bennani
# Patain - Paris -
# Therese Barden
# Jean Ivey
# Raytheon
# R.J. Reynolds
# Nestle S.A. - Switz -
# Hussein Juma
# UBAF - Paris -
# Intermaritime Bank - Geneva -
# Union Bank of Switz
# Azizullah Chaudhury
# Alfred Hartmann
# Franz Maissen
# Banque de Comm & Place - Geneva -
# Thes. Cont'l - Geneva -
# Mehmet Karamehmet
# Engin Bora
# Cukarona Group - Istanbul -
# Enza Parzalama
# 1991: indicted in US for bank fraud
# Yavuz Tezeller
# Enka Holdings
# Cargill Comas - Miami -
# plead guilty to export-related charges; paid $ 1 mil fine
# Robert Abboud
# Nat. Bank of Georgia - Atlanta -
# Ghaith Pharaon
# 1991: US indictments blocked by State dept
# Wafaj Dajani
# 86/2
# Fadhil al-Marsoumi
# Comet Rice - Houston -
# Iraq grain trade
# Amman Resources - Jordan -
# Gearbulk - Norway -
# Louis Dreyfus - NY -
# joint venture - Aqaba -
# Cont'l Grain - NY -
# Leigh Ann New
# 89/3
# 88/3
# 87/3
# 86/3
# Araba Holdings - Aqaba -
# Lewis Preston
# Morgan Guaranty - NY -
# Paul von Wedel
# 84/3
# 1991: indicted in US on 347 counts of bank fraud; plead guilty to 60 counts; later reneged on deal; plead guilty to 7 counts; sentenced to 3 years
# Lux bank account
# Christopher Drogoul
# 83/3
# Rogers and Wells - NY -
# Bruce Rappaport
# Commodity Credit Corp
# John Block sec 1981-6
# Robert Mosbacher sec 1989-92
# Commerce dept
# Agriculture dept
# William Casey dir CIA 1981-7 chmn SEC 1973-4
# Ronald Reagan pres US 1981-9
# George Bush vp US 1981-9 pres US 1989-93
# US Gov't
# Maxwell Rabb US amb to Italy 1981-9
# Guiseppe Vincenzino
# Lavoro Bank - Switz -
# Ademaro Lanzara
# Gianipiero Cantoni
# [1]
# 1988: convicted in US for fraud & money laundering; paid fine
# Entrade Int'l - NY -
# 85/3
# Cafa Baga
# Goran Gazivoda
# Rinato Gundagnini
# Vinko Mir
# BCCI S.A.
# Ljubljanska Banka - Yugo -
# LBS Bank - NY -
# Lawrence Eagleburger US sec of State 1992-3
# 83/2
# Carlo Salvatore
# Paolo Savona
# Roberto di Nisio
# 82/2
# Int'l Six - DC -
# Brent Scowcroft NSC 1989-93
# Henry Kissinger US sec of State 1973-7; NSC 1969-73
# Alan Stoga
# Kissinger Assocs - NY -
# Gianni Agnelli
# 1989: forced to resign post
# Nerio Nesi
# Mario Fallani
# 81/2
# Casalee - Lux -
# Count Ferdinando Borletti
# Fiat - Turin -
# 82/1
# Banca Nazionale del Lavoro - Atlanta -
# Pietro Lombardi
# Louis Messere
# Quirino di Mano
# Carlo Vecchi
# Vito Cannito
# Teodoro Monaco
# 1989: forced to resign post; 1991: indicted in Italy for fraud
# Giacomo Pedde
# Mario Girotti
# David Croffe
# Valsella Mech - Brescia -
# Amer Rashid al-Ubeidi
# 1988: raided by Italian police
# Paimpex
# Adnan Khairallah defense min
# 1993: indicted in Italy for criminal conspiracy 1995: indicted for murder
# Giulio Andreotti PM Italy 1972-3, 1976-9, 1989-91; foreign min 1983-9
# 1993: indicted in Italy for fraud & corruption 1994: convicted; sentenced to 8 yrs fled to Tunisia
# Foreign Min
# Benito Craxi PM Italy 1983-7
# 80/2
# BNL No. Amer - NY -
# Francesco Bignardi
# Gov't of Italy
# Lamberto Dini PM Italy 1995-6
# Guido Carli
# Treasury Min
# SACE
# Defense Min
# Fincant Riuniti Navali - Genua -
# Oto Melara - La Spezia -
# Paolo de Vito
# Banca Nazionale del Lavoro - Rome -
# Alberto Ferrari

# %%
# make a graph object to fill, using nx library
# documentation: https://networkx.org/documentation/stable/tutorial.html

Lombardi = nx.Graph()

# %%
# add nodes from lombardi data

for node in data["nodes"]:
  Lombardi.add_node(node['id'], name=node['name'], type=node['type'])

# %%
# add edges, or links from lombardi data

for link in data["links"]:
    # sometimes the 'amount' field is empty; handle this case
    amount = link["amount"] if link["amount"] else None
    Lombardi.add_edge(link["source"], link["target"], amount=amount, type=link["type"])

# %%
# see how many nodes + edges have been added

num_nodes = Lombardi.number_of_nodes()
num_edges = Lombardi.number_of_edges()

num_nodes, num_edges
# Out:
# (342, 427)

# %%
# make the network graph!

# generate the layout of the graph
# there are options: https://networkx.org/documentation/stable/reference/drawing.html
# most of the ones with "_layout" in the name listed on the left should work - try other layouts!
# (other layouts may need different parameters, formatting, etc.)

# spring_layout documentation: https://networkx.org/documentation/stable/reference/generated/networkx.drawing.layout.spring_layout.html

pos = nx.spring_layout(Lombardi, k=0.5)
# play with k value - what happens?!
# pos is now a dictionary filled with node positions

# get the node positions, fill x and y lists
node_x = []
node_y = []
for node in Lombardi.nodes():
    x, y = pos[node]
    node_x.append(x)
    node_y.append(y)

# create nodes on the graph, plotly
# check up top: go = plotly graph objects
node_trace = go.Scatter(
    x=node_x, y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        size=12, # marker size, circles from Scatter
        color='beige',
        line_width=1
    ),
    text=[Lombardi.nodes[node]['name'] for node in Lombardi.nodes()]  # hover text
)

# get the edge positions
edge_x = []
edge_y = []
for edge in Lombardi.edges():
    x0, y0 = pos[edge[0]]
    x1, y1 = pos[edge[1]]
    edge_x.extend([x0, x1, 'None'])  # Add 'None' to create the line segments, "breaks" after those 2 points
    edge_y.extend([y0, y1, 'None'])

# create edges on the graph, plotly
edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color='gray'),
    hoverinfo='none',
    mode='lines'
)


# Create the figure
fig = go.Figure(data=[edge_trace, node_trace],
          layout=go.Layout(
              title='<br>after Lombardi: <br>Banco Nazionale del Lavoro, Reagan, Bush, Thatcher, and the Arming of Iraq, c. 1979-1990 <br>(4th version). 1998',
              titlefont_size=14,
              showlegend=False,
              hovermode='closest',
              margin=dict(b=20,l=5,r=5,t=40),
              annotations=[ dict(
                  text="No. of nodes: {0}, No. of edges: {1}".format(num_nodes, num_edges),
                  showarrow=False,
                  xref="paper", yref="paper",
                  x=0.005, y=-0.002 ) ],
              xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
              yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
          )

# change parameters as design choices ...
# figure documentation: https://plotly.com/python-api-reference/generated/plotly.graph_objects.Figure.html
fig.update_layout(plot_bgcolor='#f7f1e1', paper_bgcolor='#f7f1e1', font_family="Courier New", title_font_family="Courier New",)

# Show the figure
fig.show()

# 💥 save as HTML ... !! for future interactive use !!
fig.write_html("lombardi-network1.html")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="b8825cc0-0c3a-4cc2-b935-878cec1fb9b2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b8825cc0-0c3a-4cc2-b935-878cec1fb9b2")) {                    Plotly.newPlot(                        "b8825cc0-0c3a-4cc2-b935-878cec1fb9b2",                        [{"hoverinfo":"none","line":{"color":"gray","width":0.5},"mode":"lines","x":[-0.927301754179146,-0.9128674552011117,"None",-0.9128674552011117,-0.34670364834487716,"None",0.3769544301894964,-0.34670364834487716,"None",0.3769544301894964,-0.3832062328886354,"None",-0.8923244477345743,-0.3832062328886354,"None",-0.8923244477345743,-0.04600370787781357,"None",0.3297769878432138,0.17977112810854678,"None",-0.009593285780014924,-0.08578082502092468,"None",-0.009593285780014924,0.12528636668365958,"None",0.38544132985218643,0.12528636668365958,"None",-0.0006137738678822618,0.12528636668365958,"None",0.12528636668365958,-0.08578082502092468,"None",0.12528636668365958,-0.23830517656907052,"None",0.09447469583204557,-0.23830517656907052,"None",-0.18685852273789533,-0.23830517656907052,"None",-0.40470151561796924,-0.5932888826265612,"None",-0.5932888826265612,-0.2065786885982735,"None",-0.23830517656907052,-0.1620433545254959,"None",-0.23830517656907052,0.2809369318687578,"None",-0.23830517656907052,-0.642453710989543,"None",-0.23830517656907052,-0.2065786885982735,"None",-0.23830517656907052,-0.5493326946878619,"None",0.2809369318687578,-0.2065786885982735,"None",0.2809369318687578,-0.16997202107964127,"None",-0.642453710989543,-0.2065786885982735,"None",-0.642453710989543,-0.16997202107964127,"None",-0.2065786885982735,-0.5493326946878619,"None",-0.2065786885982735,0.17977112810854678,"None",-0.5493326946878619,-0.16997202107964127,"None",-0.16997202107964127,0.40996296925246584,"None",0.6051386529378355,0.36276192360199444,"None",0.6051386529378355,0.17977112810854678,"None",0.36276192360199444,0.40996296925246584,"None",0.23832841441362868,0.17977112810854678,"None",0.23832841441362868,0.5085939022272152,"None",0.5085939022272152,0.660511690191142,"None",0.5085939022272152,0.7853948604432063,"None",0.9279281807303076,0.9281203319906867,"None",0.660511690191142,0.9281203319906867,"None",0.8905257421394026,0.9281203319906867,"None",0.8905257421394026,0.47362413296749906,"None",0.9281203319906867,0.22898865339645724,"None",0.9281203319906867,0.7853948604432063,"None",0.47362413296749906,0.7803280740974722,"None",0.47362413296749906,0.22898865339645724,"None",0.7905504857658959,0.22898865339645724,"None",-0.914104632912549,0.22898865339645724,"None",0.22898865339645724,0.4432678166054126,"None",-0.04600370787781357,0.178967499617896,"None",0.178967499617896,-0.23490026813992596,"None",0.279215572134449,-0.23490026813992596,"None",0.279215572134449,0.4432678166054126,"None",-0.23490026813992596,0.04968320385759598,"None",0.03391734026215382,0.04968320385759598,"None",0.18077732779692218,-0.29406844839764384,"None",-0.7956886102553343,-0.29406844839764384,"None",-0.29406844839764384,0.04968320385759598,"None",-0.29406844839764384,0.2395658537889892,"None",0.04968320385759598,0.35171260603567744,"None",0.35171260603567744,-0.38661294267796,"None",0.35171260603567744,0.40996296925246584,"None",0.9235221840654204,0.4432678166054126,"None",0.9235221840654204,0.6282407708226679,"None",0.9235221840654204,0.40996296925246584,"None",0.6282407708226679,0.9911689827137227,"None",-0.8316856387782123,-0.23979308313262804,"None",0.023823523411210988,-0.818478167089673,"None",-0.8862813605532875,-0.818478167089673,"None",-0.818478167089673,-0.29000689102506405,"None",0.3739761051186426,0.24551589441101054,"None",-0.29000689102506405,0.24551589441101054,"None",-0.29000689102506405,0.30346995841741226, ...

# %%
link_colors = [freeport_graph.edges[edge]['type'] for edge in freeport_graph.edges()]
link_colors_indexes = list(set(link_colors))
print(len(link_colors_indexes))  # 3 colors
link_colors_hex = ["#730058", "#fae08a", "#b06636"]
link_colors_all = [link_colors_hex[link_colors_indexes.index(edge)] for edge in link_colors]
# Out:
# 3

# %%
# now, on your own!

# choose another Lombardi dataset: https://lombardinetworks.net/networks/the-networks/

# repeat the above steps to get a 2nd interactive network diagram
with open('/content/freeport.json', 'r') as f:
    data_freeport = json.load(f)

freeport_graph = nx.Graph()
for node in data_freeport["nodes"]:
    freeport_graph.add_node(node['id'], name=node['name'], type=node['type'])

for link in data_freeport["links"]:
    amount = link["amount"] or None
    freeport_graph.add_edge(link["source"], link["target"], amount=amount, type=link["type"])

num_nodes = freeport_graph.number_of_nodes()
num_edges = freeport_graph.number_of_edges()

print(num_nodes, num_edges)

# change some parameters:
freeport_layout = nx.planar_layout(freeport_graph, scale=1)

# when you define the position (for example, pos = nx.spring_layout(Lombardi, k=0.5)) - change the layout (see documentation); change k; see what happens!
# change the colors, fonts, styling the figure (.update_layout function, https://plotly.com/python/reference/layout/)
# can you change what is the content of the hover text?

node_x = []
node_y = []
for node in freeport_graph.nodes():
    x, y = freeport_layout[node]
    node_x.append(x)
    node_y.append(y)

# print(node_x, node_y)

colors = [freeport_graph.nodes[node]['type'] for node in freeport_graph.nodes()]

def choose_color(t):
  if t.endswith("Person"):
    return "#7f7007"
  elif t.endswith("Institution"):
    return "#72e13f"
  else:
    return "#f39ada"

colors = list(map(choose_color, colors))
# create nodes on the graph, plotly
# check up top: go = plotly graph objects
node_trace = go.Scatter(
    x=node_x,
    y=node_y,
    mode='markers',
    hoverinfo='text',
    marker=dict(
        size=12, # marker size, circles from Scatter
        color=colors,
        line_width=1
    ),
    text=[freeport_graph.nodes[node]['name'] for node in freeport_graph.nodes()]  # hover text
)

# get the edge positions
edge_x = []
edge_y = []
for edge in freeport_graph.edges():
    x0, y0 = freeport_layout[edge[0]]
    x1, y1 = freeport_layout[edge[1]]
    edge_x.extend([x0, x1, 'None'])  # Add 'None' to create the line segments, "breaks" after those 2 points
    edge_y.extend([y0, y1, 'None'])

link_colors = [freeport_graph.edges[edge]['type'] for edge in freeport_graph.edges()]
link_colors = list(set(link_colors))


# create edges on the graph, plotly
edge_trace = go.Scatter(
    x=edge_x, y=edge_y,
    line=dict(width=0.5, color="#960559"),
    hoverinfo='none',
    mode='lines'
)


# Create the figure
fig = go.Figure(data=[edge_trace, node_trace],
          layout=go.Layout(
              title='Freeport Lombardi',
              titlefont_size=14,
              showlegend=True,
              title_font_shadow="auto",
              hovermode='closest',
              margin=dict(b=20,l=5,r=5,t=40),
              annotations=[ dict(
                  text="No. of nodes: {0}, No. of edges: {1}".format(num_nodes, num_edges),
                  showarrow=False,
                  xref="paper", yref="paper",
                  x=0.005, y=-0.002 ) ],
              xaxis=dict(showgrid=False, zeroline=False, showticklabels=False),
              yaxis=dict(showgrid=False, zeroline=False, showticklabels=False))
          )

# change parameters as design choices ...
# figure documentation: https://plotly.com/python-api-reference/generated/plotly.graph_objects.Figure.html
fig.update_layout(
    plot_bgcolor='#f7f1e1', paper_bgcolor='#f1f1e1', font_family="Courier New", title_font_family="Courier New",
)

# Show the figure
fig.show()

fig.write_html("lombardi-freeport-network.html")
# Out:
# 48 49
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="ba9a075c-60cd-41a7-9361-44181aa40707" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ba9a075c-60cd-41a7-9361-44181aa40707")) {                    Plotly.newPlot(                        "ba9a075c-60cd-41a7-9361-44181aa40707",                        [{"hoverinfo":"none","line":{"color":"#960559","width":0.5},"mode":"lines","x":[-1.0,0.9927797833935019,"None",-1.0,-0.9133574007220218,"None",-1.0,0.8628158844765345,"None",0.9927797833935019,0.884476534296029,"None",0.9927797833935019,0.9061371841155236,"None",0.9927797833935019,0.9277978339350182,"None",0.8628158844765345,-0.8700361010830325,"None",-0.8700361010830325,-0.8916967509025271,"None",0.27797833935018057,0.38628158844765353,"None",0.38628158844765353,0.21299638989169684,"None",0.38628158844765353,0.4729241877256319,"None",0.38628158844765353,0.5162454873646211,"None",0.38628158844765353,0.4296028880866427,"None",0.38628158844765353,0.4079422382671481,"None",0.38628158844765353,0.38628158844765353,"None",0.38628158844765353,0.45126353790613727,"None",0.38628158844765353,0.6462093862815885,"None",0.5162454873646211,0.21299638989169684,"None",0.21299638989169684,-0.5884476534296029,"None",0.21299638989169684,0.0830324909747293,"None",0.21299638989169684,0.10469314079422389,"None",0.21299638989169684,0.1263537906137185,"None",0.21299638989169684,0.6462093862815885,"None",0.0830324909747293,0.01805054151624554,"None",0.0830324909747293,0.03971119133574013,"None",0.01805054151624554,-0.17689530685920574,"None",0.01805054151624554,-0.0902527075812274,"None",0.01805054151624554,-0.06859205776173281,"None",-0.17689530685920574,-0.19855595667870032,"None",-0.0902527075812274,-0.15523465703971115,"None",-0.0902527075812274,-0.11191335740072199,"None",-0.19855595667870032,-0.5451263537906137,"None",-0.19855595667870032,-0.4368231046931408,"None",-0.19855595667870032,-0.30685920577617326,"None",-0.19855595667870032,-0.2851985559566787,"None",-0.30685920577617326,-0.3285198555956679,"None",-0.3285198555956679,-0.35018050541516244,"None",-0.35018050541516244,-0.4151624548736462,"None",0.1263537906137185,0.10469314079422389,"None",0.4729241877256319,0.45126353790613727,"None",0.6462093862815885,0.6678700361010832,"None",0.6462093862815885,-0.848375451263538,"None",0.6462093862815885,-0.6101083032490975,"None",0.6678700361010832,0.7761732851985561,"None",-0.6101083032490975,-0.6750902527075813,"None",-0.6101083032490975,-0.6534296028880867,"None",-0.6750902527075813,-0.7617328519855596,"None",-0.6750902527075813,-0.6967509025270758,"None",0.7111913357400723,0.6895306859205778,"None"],"y":[-0.26489169675090257,-0.26489169675090257,"None",-0.26489169675090257,-0.1782490974729242,"None",-0.26489169675090257,-0.22157039711191337,"None",-0.26489169675090257,-0.24323104693140796,"None",-0.26489169675090257,-0.22157039711191337,"None",-0.26489169675090257,-0.19990974729241878,"None",-0.22157039711191337,-0.1782490974729242,"None",-0.1782490974729242,-0.19990974729241878,"None",0.03835740072202168,0.1683212996389892,"None",0.1683212996389892,-0.004963898916967497,"None",0.1683212996389892,0.060018050541516266,"None",0.1683212996389892,0.01669675090252709,"None",0.1683212996389892,0.10333935018050544,"None",0.1683212996389892,0.12500000000000003,"None",0.1683212996389892,0.14666064981949462,"None",0.1683212996389892,0.08167870036101085,"None",0.1683212996389892,-0.09160649819494585,"None",0.01669675090252709,-0.004963898916967497,"None",-0.004963898916967497,-0.026624548736462084,"None",-0.004963898916967497,0.03835740072202168,"None",-0.004963898916967497,0.060018050541516266,"None",-0.004963898916967497,0.08167870036101085,"None",-0.004963898916967497,-0.09160649819494585,"None",0.0383 ...

# %%
# options to expand this, if time or later:

# 3d network graph https://plotly.com/python/v3/3d-network-graph/

# do some text transformation to get the type attribute - can you incorporate it into the graph? color code the nodes?

# try d3, try cytoscape! https://d3-graph-gallery.com/graph/network_basic.html, https://cytoscape.org/

# %% [markdown]
# ⚛️ citations:
#
# - [NetworkX/Plotly tutorial](https://python.plainenglish.io/create-a-network-graph-in-python-8829e0ec6741)
# - [NetworkX Documentation](https://networkx.org/documentation/stable/index.html)
# - [Plotly Documentation](https://plotly.com/python/network-graphs/)
# - [Lombardi Networks data](https://lombardinetworks.net/networks/the-networks/)

# %% [markdown]
# ## 🪼 when you are finished! submit: 🖇️
#
# 1. Download this notebook as an `.ipynb` file (File -> Download)
# 2. Go to [this link](https://airtable.com/appJ1zoJbOnRhJYPQ/shr6LkH556ySC6uqU) and upload the file via the form.
# 3. Then you're done! In-class labs are counted as participation credit.
